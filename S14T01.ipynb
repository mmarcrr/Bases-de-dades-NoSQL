# %% [markdown]
# # S14 T01: Tasca base de dades NoSQL
# ## Descripció
#
# Comencem a familiaritzar-nos amb bases de dades NoSQL !!! Comencem amb uns quants exercicis bàsics
# ## Nivell 1
# ### - Exercici 1
#
# Crea una base de dades NoSQL utilitzant MongoDB. Afegeix-li algunes dades d'exemple que et permetin comprovar que ets capaç de processar-ne la informació de manera bàsica.
# ### - Exercici 2
#
# Connecta la base de dades NoSQL a Python utilitzant per exemple pymongo.

# %%
import pymongo
import numpy as np
import pandas as pd
import requests
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate



# %matplotlib inline

# %%
col_name='llum'
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = client[col_name]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'llum')

# %%
url='https://api.preciodelaluz.org/v1/prices/all?zone=PCB'
headers = {
        'Content-type': 'application/json'
    }

response = requests.get(url, headers=headers)

template_dct =response.json()
for dic in template_dct:
    print(template_dct[dic])
    #result = db.llum.insert_one(template_dct[dic])
    #print('Inserted post id %s ' % result.inserted_id)
# Out:
# {'date': '15-04-2022', 'hour': '00-01', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 274.52, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '01-02', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 265.48, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '02-03', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 262.97, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '03-04', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 260.87, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '04-05', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 259.76, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '05-06', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 265.41, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '06-07', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 272.52, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '07-08', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 288.36, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '08-09', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 329.67, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '09-10', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 317.06, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '10-11', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 316.26, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '11-12', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 291.17, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '12-13', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 291.17, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '13-14', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 288.2, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '14-15', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 232.35, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '15-16', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 229.63, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '16-17', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 235.35, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '17-18', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 253.72, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '18-19', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 328.34, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '19-20', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 364.26, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '20-21', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 366.88, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '21-22', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 365.16, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '22-23', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 318.81, 'units': '€/Mwh'}
# {'date': '15-04-2022', 'hour': '23-24', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 299.06, 'units': '€/Mwh'}

# %%
for dic in template_dct:
    result = db.llum.insert_one(template_dct[dic])
    print('Inserted post id %s ' % result.inserted_id)
# Out:
# Inserted post id 6259afd8e78c0c53b84ca7ea
# Inserted post id 6259afd8e78c0c53b84ca7eb
# Inserted post id 6259afd8e78c0c53b84ca7ec
# Inserted post id 6259afd8e78c0c53b84ca7ed
# Inserted post id 6259afd8e78c0c53b84ca7ee
# Inserted post id 6259afd8e78c0c53b84ca7ef
# Inserted post id 6259afd8e78c0c53b84ca7f0
# Inserted post id 6259afd8e78c0c53b84ca7f1
# Inserted post id 6259afd8e78c0c53b84ca7f2
# Inserted post id 6259afd8e78c0c53b84ca7f3
# Inserted post id 6259afd8e78c0c53b84ca7f4
# Inserted post id 6259afd8e78c0c53b84ca7f5
# Inserted post id 6259afd8e78c0c53b84ca7f6
# Inserted post id 6259afd8e78c0c53b84ca7f7
# Inserted post id 6259afd8e78c0c53b84ca7f8
# Inserted post id 6259afd8e78c0c53b84ca7f9
# Inserted post id 6259afd8e78c0c53b84ca7fa
# Inserted post id 6259afd8e78c0c53b84ca7fb
# Inserted post id 6259afd8e78c0c53b84ca7fc
# Inserted post id 6259afd8e78c0c53b84ca7fd
# Inserted post id 6259afd8e78c0c53b84ca7fe
# Inserted post id 6259afd8e78c0c53b84ca7ff
# Inserted post id 6259afd8e78c0c53b84ca800
# Inserted post id 6259afd8e78c0c53b84ca801

# %%
db.list_collection_names()
# Out:
# ['llum', 'test']

# %%
for item in db[col_name].find():
    pprint(item)
# Out:
# {'_id': ObjectId('62547faa9e5028dd78f8b144'),
#  'date': '11-04-2022',
#  'hour': '00-01',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 203.38,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b145'),
#  'date': '11-04-2022',
#  'hour': '01-02',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 167.5,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b146'),
#  'date': '11-04-2022',
#  'hour': '02-03',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 149.34,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b147'),
#  'date': '11-04-2022',
#  'hour': '03-04',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 156.97,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b148'),
#  'date': '11-04-2022',
#  'hour': '04-05',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 176.15,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b149'),
#  'date': '11-04-2022',
#  'hour': '05-06',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 213.48,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b14a'),
#  'date': '11-04-2022',
#  'hour': '06-07',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 219.8,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b14b'),
#  'date': '11-04-2022',
#  'hour': '07-08',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 319.81,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b14c'),
#  'date': '11-04-2022',
#  'hour': '08-09',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 361.44,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b14d'),
#  'date': '11-04-2022',
#  'hour': '09-10',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 337.01,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b14e'),
#  'date': '11-04-2022',
#  'hour': '10-11',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 339.75,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b14f'),
#  'date': '11-04-2022',
#  'hour': '11-12',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 268.05,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b150'),
#  'date': '11-04-2022',
#  'hour': '12-13',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 233.59,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b151'),
#  'date': '11-04-2022',
#  'hour': '13-14',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 195.31,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b152'),
#  'date': '11-04-2022',
#  'hour': '14-15',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 118.35,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b153'),
#  'date': '11-04-2022',
#  'hour': '15-16',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 111.42,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b154'),
#  'date': '11-04-2022',
#  'hour': '16-17',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 120.62,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b155'),
#  'date': '11-04-2022',
#  'hour': '17-18',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 179.98,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b156'),
#  'date': '11-04-2022',
#  'hour': '18-19',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 273.26,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b157'),
#  'date': '11-04-2022',
#  'hour': '19-20',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 373.24,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b158'),
#  'date': '11-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 403.3,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b159'),
#  'date': '11-04-2022',
#  'hour': '21-22',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 404.51,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b15a'),
#  'date': '11-04-2022',
#  'hour': '22-23',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 342.78,
#  'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b15b'),
#  'date': '11-04-2022',
#  'hour': '23-24',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 298.19,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d2'),
#  'date': '13-04-2022',
#  'hour': '00-01',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 300.27,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d3'),
#  'date': '13-04-2022',
#  'hour': '01-02',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 290.25,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d4'),
#  'date': '13-04-2022',
#  'hour': '02-03',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 280.93,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d5'),
#  'date': '13-04-2022',
#  'hour': '03-04',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 261.03,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d6'),
#  'date': '13-04-2022',
#  'hour': '04-05',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 248.66,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d7'),
#  'date': '13-04-2022',
#  'hour': '05-06',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 270.2,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d8'),
#  'date': '13-04-2022',
#  'hour': '06-07',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 310.61,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7d9'),
#  'date': '13-04-2022',
#  'hour': '07-08',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 317.75,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7da'),
#  'date': '13-04-2022',
#  'hour': '08-09',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 353.36,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7db'),
#  'date': '13-04-2022',
#  'hour': '09-10',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 336.28,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7dc'),
#  'date': '13-04-2022',
#  'hour': '10-11',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 369.53,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7dd'),
#  'date': '13-04-2022',
#  'hour': '11-12',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 357.54,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7de'),
#  'date': '13-04-2022',
#  'hour': '12-13',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 348.77,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7df'),
#  'date': '13-04-2022',
#  'hour': '13-14',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 323.67,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e0'),
#  'date': '13-04-2022',
#  'hour': '14-15',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 270.9,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e1'),
#  'date': '13-04-2022',
#  'hour': '15-16',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 268.39,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e2'),
#  'date': '13-04-2022',
#  'hour': '16-17',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 275.31,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e3'),
#  'date': '13-04-2022',
#  'hour': '17-18',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 301.67,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e4'),
#  'date': '13-04-2022',
#  'hour': '18-19',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 343.95,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e5'),
#  'date': '13-04-2022',
#  'hour': '19-20',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 372.54,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e6'),
#  'date': '13-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 383.46,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e7'),
#  'date': '13-04-2022',
#  'hour': '21-22',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 385.23,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e8'),
#  'date': '13-04-2022',
#  'hour': '22-23',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 333.51,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256a42590cf8b20bf67c7e9'),
#  'date': '13-04-2022',
#  'hour': '23-24',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 313.09,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7ed'),
#  'date': '13-04-2022',
#  'hour': '00-01',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 300.27,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7ee'),
#  'date': '13-04-2022',
#  'hour': '01-02',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 290.25,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7ef'),
#  'date': '13-04-2022',
#  'hour': '02-03',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 280.93,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f0'),
#  'date': '13-04-2022',
#  'hour': '03-04',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 261.03,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f1'),
#  'date': '13-04-2022',
#  'hour': '04-05',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 248.66,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f2'),
#  'date': '13-04-2022',
#  'hour': '05-06',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 270.2,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f3'),
#  'date': '13-04-2022',
#  'hour': '06-07',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 310.61,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f4'),
#  'date': '13-04-2022',
#  'hour': '07-08',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 317.75,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f5'),
#  'date': '13-04-2022',
#  'hour': '08-09',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 353.36,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f6'),
#  'date': '13-04-2022',
#  'hour': '09-10',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 336.28,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f7'),
#  'date': '13-04-2022',
#  'hour': '10-11',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 369.53,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f8'),
#  'date': '13-04-2022',
#  'hour': '11-12',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 357.54,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7f9'),
#  'date': '13-04-2022',
#  'hour': '12-13',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 348.77,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7fa'),
#  'date': '13-04-2022',
#  'hour': '13-14',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 323.67,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7fb'),
#  'date': '13-04-2022',
#  'hour': '14-15',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 270.9,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7fc'),
#  'date': '13-04-2022',
#  'hour': '15-16',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 268.39,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7fd'),
#  'date': '13-04-2022',
#  'hour': '16-17',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 275.31,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7fe'),
#  'date': '13-04-2022',
#  'hour': '17-18',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 301.67,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c7ff'),
#  'date': '13-04-2022',
#  'hour': '18-19',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 343.95,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c800'),
#  'date': '13-04-2022',
#  'hour': '19-20',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 372.54,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c801'),
#  'date': '13-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 383.46,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c802'),
#  'date': '13-04-2022',
#  'hour': '21-22',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 385.23,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c803'),
#  'date': '13-04-2022',
#  'hour': '22-23',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 333.51,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6256e15790cf8b20bf67c804'),
#  'date': '13-04-2022',
#  'hour': '23-24',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 313.09,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c806'),
#  'date': '14-04-2022',
#  'hour': '00-01',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 291.91,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c807'),
#  'date': '14-04-2022',
#  'hour': '01-02',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 266.01,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c808'),
#  'date': '14-04-2022',
#  'hour': '02-03',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 260.35,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c809'),
#  'date': '14-04-2022',
#  'hour': '03-04',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 259.75,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c80a'),
#  'date': '14-04-2022',
#  'hour': '04-05',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 261.96,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c80b'),
#  'date': '14-04-2022',
#  'hour': '05-06',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 267.19,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c80c'),
#  'date': '14-04-2022',
#  'hour': '06-07',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 304.46,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c80d'),
#  'date': '14-04-2022',
#  'hour': '07-08',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 306.81,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c80e'),
#  'date': '14-04-2022',
#  'hour': '08-09',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 339.75,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c80f'),
#  'date': '14-04-2022',
#  'hour': '09-10',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 323.46,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c810'),
#  'date': '14-04-2022',
#  'hour': '10-11',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 341.87,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c811'),
#  'date': '14-04-2022',
#  'hour': '11-12',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 320.7,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c812'),
#  'date': '14-04-2022',
#  'hour': '12-13',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 311.28,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c813'),
#  'date': '14-04-2022',
#  'hour': '13-14',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 316.25,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c814'),
#  'date': '14-04-2022',
#  'hour': '14-15',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 269.68,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c815'),
#  'date': '14-04-2022',
#  'hour': '15-16',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 271.43,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c816'),
#  'date': '14-04-2022',
#  'hour': '16-17',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 271.03,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c817'),
#  'date': '14-04-2022',
#  'hour': '17-18',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 282.08,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c818'),
#  'date': '14-04-2022',
#  'hour': '18-19',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 359.26,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c819'),
#  'date': '14-04-2022',
#  'hour': '19-20',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 375.81,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c81a'),
#  'date': '14-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 405.83,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c81b'),
#  'date': '14-04-2022',
#  'hour': '21-22',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 393.7,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c81c'),
#  'date': '14-04-2022',
#  'hour': '22-23',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 338.95,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6257bab590cf8b20bf67c81d'),
#  'date': '14-04-2022',
#  'hour': '23-24',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 322.83,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d1'),
#  'date': '15-04-2022',
#  'hour': '00-01',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 274.52,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d2'),
#  'date': '15-04-2022',
#  'hour': '01-02',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 265.48,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d3'),
#  'date': '15-04-2022',
#  'hour': '02-03',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 262.97,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d4'),
#  'date': '15-04-2022',
#  'hour': '03-04',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 260.87,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d5'),
#  'date': '15-04-2022',
#  'hour': '04-05',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 259.76,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d6'),
#  'date': '15-04-2022',
#  'hour': '05-06',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 265.41,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d7'),
#  'date': '15-04-2022',
#  'hour': '06-07',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 272.52,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d8'),
#  'date': '15-04-2022',
#  'hour': '07-08',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 288.36,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7d9'),
#  'date': '15-04-2022',
#  'hour': '08-09',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 329.67,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7da'),
#  'date': '15-04-2022',
#  'hour': '09-10',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 317.06,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7db'),
#  'date': '15-04-2022',
#  'hour': '10-11',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 316.26,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7dc'),
#  'date': '15-04-2022',
#  'hour': '11-12',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 291.17,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7dd'),
#  'date': '15-04-2022',
#  'hour': '12-13',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 291.17,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7de'),
#  'date': '15-04-2022',
#  'hour': '13-14',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 288.2,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7df'),
#  'date': '15-04-2022',
#  'hour': '14-15',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 232.35,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e0'),
#  'date': '15-04-2022',
#  'hour': '15-16',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 229.63,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e1'),
#  'date': '15-04-2022',
#  'hour': '16-17',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 235.35,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e2'),
#  'date': '15-04-2022',
#  'hour': '17-18',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 253.72,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e3'),
#  'date': '15-04-2022',
#  'hour': '18-19',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 328.34,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e4'),
#  'date': '15-04-2022',
#  'hour': '19-20',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 364.26,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e5'),
#  'date': '15-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 366.88,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e6'),
#  'date': '15-04-2022',
#  'hour': '21-22',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 365.16,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e7'),
#  'date': '15-04-2022',
#  'hour': '22-23',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 318.81,
#  'units': '€/Mwh'}
# {'_id': ObjectId('625924bae78c0c53b84ca7e8'),
#  'date': '15-04-2022',
#  'hour': '23-24',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 299.06,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7ea'),
#  'date': '15-04-2022',
#  'hour': '00-01',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 274.52,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7eb'),
#  'date': '15-04-2022',
#  'hour': '01-02',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 265.48,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7ec'),
#  'date': '15-04-2022',
#  'hour': '02-03',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 262.97,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7ed'),
#  'date': '15-04-2022',
#  'hour': '03-04',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 260.87,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7ee'),
#  'date': '15-04-2022',
#  'hour': '04-05',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 259.76,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7ef'),
#  'date': '15-04-2022',
#  'hour': '05-06',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 265.41,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f0'),
#  'date': '15-04-2022',
#  'hour': '06-07',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 272.52,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f1'),
#  'date': '15-04-2022',
#  'hour': '07-08',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 288.36,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f2'),
#  'date': '15-04-2022',
#  'hour': '08-09',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 329.67,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f3'),
#  'date': '15-04-2022',
#  'hour': '09-10',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 317.06,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f4'),
#  'date': '15-04-2022',
#  'hour': '10-11',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 316.26,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f5'),
#  'date': '15-04-2022',
#  'hour': '11-12',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 291.17,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f6'),
#  'date': '15-04-2022',
#  'hour': '12-13',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 291.17,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f7'),
#  'date': '15-04-2022',
#  'hour': '13-14',
#  'is-cheap': False,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 288.2,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f8'),
#  'date': '15-04-2022',
#  'hour': '14-15',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 232.35,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f9'),
#  'date': '15-04-2022',
#  'hour': '15-16',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 229.63,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fa'),
#  'date': '15-04-2022',
#  'hour': '16-17',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 235.35,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fb'),
#  'date': '15-04-2022',
#  'hour': '17-18',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 253.72,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fc'),
#  'date': '15-04-2022',
#  'hour': '18-19',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 328.34,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fd'),
#  'date': '15-04-2022',
#  'hour': '19-20',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 364.26,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fe'),
#  'date': '15-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 366.88,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7ff'),
#  'date': '15-04-2022',
#  'hour': '21-22',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 365.16,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca800'),
#  'date': '15-04-2022',
#  'hour': '22-23',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 318.81,
#  'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca801'),
#  'date': '15-04-2022',
#  'hour': '23-24',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 299.06,
#  'units': '€/Mwh'}

# %% [markdown]
# ## Nivell 2
# ### - Exercici 1
#
# Carega algunes consultes senzilles a un Pandas Dataframe.

# %%
col = db.llum.find()

for item in col:
    print(item.keys())
    for rowns in item.keys():
        print(item[rowns])
# Out:
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b144
# 11-04-2022
# 00-01
# False
# True
# PVPC
# 203.38
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b145
# 11-04-2022
# 01-02
# True
# True
# PVPC
# 167.5
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b146
# 11-04-2022
# 02-03
# True
# True
# PVPC
# 149.34
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b147
# 11-04-2022
# 03-04
# True
# True
# PVPC
# 156.97
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b148
# 11-04-2022
# 04-05
# False
# True
# PVPC
# 176.15
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b149
# 11-04-2022
# 05-06
# False
# True
# PVPC
# 213.48
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b14a
# 11-04-2022
# 06-07
# False
# True
# PVPC
# 219.8
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b14b
# 11-04-2022
# 07-08
# False
# False
# PVPC
# 319.81
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b14c
# 11-04-2022
# 08-09
# False
# False
# PVPC
# 361.44
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b14d
# 11-04-2022
# 09-10
# False
# False
# PVPC
# 337.01
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b14e
# 11-04-2022
# 10-11
# False
# False
# PVPC
# 339.75
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b14f
# 11-04-2022
# 11-12
# False
# False
# PVPC
# 268.05
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b150
# 11-04-2022
# 12-13
# False
# True
# PVPC
# 233.59
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b151
# 11-04-2022
# 13-14
# False
# True
# PVPC
# 195.31
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b152
# 11-04-2022
# 14-15
# True
# True
# PVPC
# 118.35
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b153
# 11-04-2022
# 15-16
# True
# True
# PVPC
# 111.42
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b154
# 11-04-2022
# 16-17
# True
# True
# PVPC
# 120.62
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b155
# 11-04-2022
# 17-18
# False
# True
# PVPC
# 179.98
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b156
# 11-04-2022
# 18-19
# False
# False
# PVPC
# 273.26
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b157
# 11-04-2022
# 19-20
# False
# False
# PVPC
# 373.24
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b158
# 11-04-2022
# 20-21
# False
# False
# PVPC
# 403.3
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b159
# 11-04-2022
# 21-22
# False
# False
# PVPC
# 404.51
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b15a
# 11-04-2022
# 22-23
# False
# False
# PVPC
# 342.78
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 62547faa9e5028dd78f8b15b
# 11-04-2022
# 23-24
# False
# False
# PVPC
# 298.19
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6256a42590cf8b20bf67c7
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7df
# 15-04-2022
# 14-15
# True
# True
# PVPC
# 232.35
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e0
# 15-04-2022
# 15-16
# True
# True
# PVPC
# 229.63
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e1
# 15-04-2022
# 16-17
# True
# True
# PVPC
# 235.35
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e2
# 15-04-2022
# 17-18
# True
# True
# PVPC
# 253.72
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e3
# 15-04-2022
# 18-19
# False
# False
# PVPC
# 328.34
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e4
# 15-04-2022
# 19-20
# False
# False
# PVPC
# 364.26
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e5
# 15-04-2022
# 20-21
# False
# False
# PVPC
# 366.88
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e6
# 15-04-2022
# 21-22
# False
# False
# PVPC
# 365.16
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e7
# 15-04-2022
# 22-23
# False
# False
# PVPC
# 318.81
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 625924bae78c0c53b84ca7e8
# 15-04-2022
# 23-24
# False
# False
# PVPC
# 299.06
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7ea
# 15-04-2022
# 00-01
# False
# True
# PVPC
# 274.52
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7eb
# 15-04-2022
# 01-02
# False
# True
# PVPC
# 265.48
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7ec
# 15-04-2022
# 02-03
# False
# True
# PVPC
# 262.97
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7ed
# 15-04-2022
# 03-04
# True
# True
# PVPC
# 260.87
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7ee
# 15-04-2022
# 04-05
# True
# True
# PVPC
# 259.76
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7ef
# 15-04-2022
# 05-06
# False
# True
# PVPC
# 265.41
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f0
# 15-04-2022
# 06-07
# False
# True
# PVPC
# 272.52
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f1
# 15-04-2022
# 07-08
# False
# True
# PVPC
# 288.36
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f2
# 15-04-2022
# 08-09
# False
# False
# PVPC
# 329.67
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f3
# 15-04-2022
# 09-10
# False
# False
# PVPC
# 317.06
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f4
# 15-04-2022
# 10-11
# False
# False
# PVPC
# 316.26
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f5
# 15-04-2022
# 11-12
# False
# False
# PVPC
# 291.17
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f6
# 15-04-2022
# 12-13
# False
# False
# PVPC
# 291.17
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f7
# 15-04-2022
# 13-14
# False
# True
# PVPC
# 288.2
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f8
# 15-04-2022
# 14-15
# True
# True
# PVPC
# 232.35
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7f9
# 15-04-2022
# 15-16
# True
# True
# PVPC
# 229.63
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7fa
# 15-04-2022
# 16-17
# True
# True
# PVPC
# 235.35
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7fb
# 15-04-2022
# 17-18
# True
# True
# PVPC
# 253.72
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7fc
# 15-04-2022
# 18-19
# False
# False
# PVPC
# 328.34
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7fd
# 15-04-2022
# 19-20
# False
# False
# PVPC
# 364.26
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7fe
# 15-04-2022
# 20-21
# False
# False
# PVPC
# 366.88
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca7ff
# 15-04-2022
# 21-22
# False
# False
# PVPC
# 365.16
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca800
# 15-04-2022
# 22-23
# False
# False
# PVPC
# 318.81
# €/Mwh
# dict_keys(['_id', 'date', 'hour', 'is-cheap', 'is-under-avg', 'market', 'price', 'units'])
# 6259afd8e78c0c53b84ca801
# 15-04-2022
# 23-24
# False
# False
# PVPC
# 299.06
# €/Mwh

# %%
cols = db.llum.find()

doc=cols[1]
for doc in db.llum.find({'is-under-avg':True}):
    print(doc)
# Out:
# {'_id': ObjectId('62547faa9e5028dd78f8b144'), 'date': '11-04-2022', 'hour': '00-01', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 203.38, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b145'), 'date': '11-04-2022', 'hour': '01-02', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 167.5, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b146'), 'date': '11-04-2022', 'hour': '02-03', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 149.34, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b147'), 'date': '11-04-2022', 'hour': '03-04', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 156.97, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b148'), 'date': '11-04-2022', 'hour': '04-05', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 176.15, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b149'), 'date': '11-04-2022', 'hour': '05-06', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 213.48, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8
 'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7f9'), 'date': '15-04-2022', 'hour': '15-16', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 229.63, 'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fa'), 'date': '15-04-2022', 'hour': '16-17', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 235.35, 'units': '€/Mwh'}
# {'_id': ObjectId('6259afd8e78c0c53b84ca7fb'), 'date': '15-04-2022', 'hour': '17-18', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 253.72, 'units': '€/Mwh'}

# %%
result_4 = db.llum.find({
    "price" : { "$lt" : 200, "$gt" : 100}
})

for i in result_4:
    print(i)
# Out:
# {'_id': ObjectId('62547faa9e5028dd78f8b145'), 'date': '11-04-2022', 'hour': '01-02', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 167.5, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b146'), 'date': '11-04-2022', 'hour': '02-03', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 149.34, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b147'), 'date': '11-04-2022', 'hour': '03-04', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 156.97, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b148'), 'date': '11-04-2022', 'hour': '04-05', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 176.15, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b151'), 'date': '11-04-2022', 'hour': '13-14', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 195.31, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b152'), 'date': '11-04-2022', 'hour': '14-15', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 118.35, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b153'), 'date': '11-04-2022', 'hour': '15-16', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 111.42, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b154'), 'date': '11-04-2022', 'hour': '16-17', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 120.62, 'units': '€/Mwh'}
# {'_id': ObjectId('62547faa9e5028dd78f8b155'), 'date': '11-04-2022', 'hour': '17-18', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 179.98, 'units': '€/Mwh'}

# %%
list(db.llum.aggregate([{
  "$group": { "_id":"$hour", "priceAverage":{"$avg":"$price"} }}]))
# Out:
# [{'_id': '10-11', 'priceAverage': 342.2},
#  {'_id': '17-18', 'priceAverage': 262.14},
#  {'_id': '20-21', 'priceAverage': 384.9683333333333},
#  {'_id': '12-13', 'priceAverage': 304.125},
#  {'_id': '21-22', 'priceAverage': 383.165},
#  {'_id': '02-03', 'priceAverage': 249.5816666666667},
#  {'_id': '08-09', 'priceAverage': 344.5416666666667},
#  {'_id': '18-19', 'priceAverage': 329.51666666666665},
#  {'_id': '22-23', 'priceAverage': 331.06166666666667},
#  {'_id': '09-10', 'priceAverage': 327.8583333333333},
#  {'_id': '01-02', 'priceAverage': 257.495},
#  {'_id': '04-05', 'priceAverage': 242.49166666666665},
#  {'_id': '05-06', 'priceAverage': 258.6483333333333},
#  {'_id': '03-04', 'priceAverage': 243.42},
#  {'_id': '15-16', 'priceAverage': 229.81499999999997},
#  {'_id': '16-17', 'priceAverage': 235.495},
#  {'_id': '13-14', 'priceAverage': 289.21666666666664},
#  {'_id': '11-12', 'priceAverage': 314.3616666666667},
#  {'_id': '19-20', 'priceAverage': 370.44166666666666},
#  {'_id': '00-01', 'priceAverage': 274.145},
#  {'_id': '14-15', 'priceAverage': 232.42166666666665},
#  {'_id': '23-24', 'priceAverage': 307.55333333333334},
#  {'_id': '07-08', 'priceAverage': 306.47333333333336},
#  {'_id': '06-07', 'priceAverage': 281.75333333333333}]

# %% [markdown]
# ## Nivell 3
# ### - Exercici 1
#
# Genera un resum estadístic de la informació que conté la base de dades.

# %%
db.llum.find_one(sort=[("price", pymongo.DESCENDING)])
# Out:
# {'_id': ObjectId('6257bab590cf8b20bf67c81a'),
#  'date': '14-04-2022',
#  'hour': '20-21',
#  'is-cheap': False,
#  'is-under-avg': False,
#  'market': 'PVPC',
#  'price': 405.83,
#  'units': '€/Mwh'}

# %%
db.llum.find_one(sort=[("price", pymongo.ASCENDING)])
# Out:
# {'_id': ObjectId('62547faa9e5028dd78f8b153'),
#  'date': '11-04-2022',
#  'hour': '15-16',
#  'is-cheap': True,
#  'is-under-avg': True,
#  'market': 'PVPC',
#  'price': 111.42,
#  'units': '€/Mwh'}

# %%
df_avg = pd.DataFrame(list(db.llum.aggregate(
    [
        {
            "$group": { "_id":"$hour", "priceAverage":{"$avg":"$price"}}
            
        },
        {
            "$sort": { "_id": 1 }
        }
    ]
)))
df_avg
# Out:
#       _id  priceAverage
# 0   00-01    274.145000
# 1   01-02    257.495000
# 2   02-03    249.581667
# 3   03-04    243.420000
# 4   04-05    242.491667
# 5   05-06    258.648333
# 6   06-07    281.753333
# 7   07-08    306.473333
# 8   08-09    344.541667
# 9   09-10    327.858333
# 10  10-11    342.200000
# 11  11-12    314.361667
# 12  12-13    304.125000
# 13  13-14    289.216667
# 14  14-15    232.421667
# 15  15-16    229.815000
# 16  16-17    235.495000
# 17  17-18    262.140000
# 18  18-19    329.516667
# 19  19-20    370.441667
# 20  20-21    384.968333
# 21  21-22    383.165000
# 22  22-23    331.061667
# 23  23-24    307.553333

# %%
plt.figure(figsize=(24,10))
df_avg.plot(x='_id', y='priceAverage', kind='line', ylabel='price', xlabel='hour', title='mitja cost hora')
# Out:
# <AxesSubplot:title={'center':'mitja cost hora'}, xlabel='hour', ylabel='price'>

# %%
df = pd.DataFrame(db.llum.find())
df.drop(["_id"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          144 non-null    object
#  1   hour          144 non-null    object
#  2   is-cheap      144 non-null    bool
#  3   is-under-avg  144 non-null    bool
#  4   market        144 non-null    object
#  5   price         144 non-null    float64
#  6   units         144 non-null    object
# dtypes: bool(2), float64(1), object(4)
# memory usage: 6.0+ KB

# %%
def cat_std_summary(df, column_name,):

  column = df[column_name]
  num_values = column.value_counts().shape[0]
  count_value = column.count()
  freq = column.value_counts(normalize=True)*100
  return [column_name, count_value, num_values, freq]



categorical_columns=list(df.select_dtypes(include=['object']).columns)
table = []
for column in categorical_columns:
  table.append(cat_std_summary(df,column))
print(tabulate(table, headers=["columna","num_Valors","valors","freq %"]))
# Out:
# columna      num_Valors    valors  freq %
# ---------  ------------  --------  ----------------------------
# date                144         4  13-04-2022    33.333333
#                                    15-04-2022    33.333333
#                                    11-04-2022    16.666667
#                                    14-04-2022    16.666667
#                                    Name: date, dtype: float64
# hour                144        24  00-01    4.166667
#                                    01-02    4.166667
#                                    22-23    4.166667
#                                    21-22    4.166667
#                                    20-21    4.166667
#                                    19-20    4.166667
#                                    18-19    4.166667
#                                    17-18    4.166667
#                                    16-17    4.166667
#                                    15-16    4.166667
#                                    14-15    4.166667
#                                    13-14    4.166667
#                                    12-13    4.166667
#                                    11-12    4.166667
#                                    10-11    4.166667
#                                    09-10    4.166667
#                                    08-09    4.166667
#                                    07-08    4.166667
#                                    06-07    4.166667
#                                    05-06    4.166667
#                                    04-05    4.166667
#                                    03-04    4.166667
#                                    02-03    4.166667
#                                    23-24    4.166667
#                                    Name: hour, dtype: float64
# market              144         1  PVPC    100.0
#                                    Name: market, dtype: float64
# units               144         1  €/Mwh    100.0
#                                    Name: units, dtype: float64
