# %% [markdown]
# # S14 T01: Tasca base de dades NoSQL
# ## Descripció
#
# Comencem a familiaritzar-nos amb bases de dades NoSQL !!! Comencem amb uns quants exercicis bàsics
# ## Nivell 1
# ### - Exercici 1
#
# Crea una base de dades NoSQL utilitzant MongoDB. Afegeix-li algunes dades d'exemple que et permetin comprovar que ets capaç de processar-ne la informació de manera bàsica.
# ### - Exercici 2
#
# Connecta la base de dades NoSQL a Python utilitzant per exemple pymongo.

# %%
import pymongo
import pandas as pd
import requests
from pprint import pprint

# %%
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = client["test"]

# %%
url='https://api.preciodelaluz.org/v1/prices/all?zone=PCB'
headers = {
        'Content-type': 'application/json'
    }

response = requests.get(url, headers=headers)

template_dct =response.json()
result = db.test.insert_one(template_dct)
print('Inserted post id %s ' % result.inserted_id)
# Out:
# Inserted post id 6253bcecfdd924a15fe86541

# %%
db.list_collection_names()
# Out:
# ['test']

# %%
for item in db['test'].find():
    pprint(item)
# Out:
# {'00-01': {'date': '10-04-2022',
#            'hour': '00-01',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 351.01,
#            'units': '€/Mwh'},
#  '01-02': {'date': '10-04-2022',
#            'hour': '01-02',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 339.53,
#            'units': '€/Mwh'},
#  '02-03': {'date': '10-04-2022',
#            'hour': '02-03',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 350.52,
#            'units': '€/Mwh'},
#  '03-04': {'date': '10-04-2022',
#            'hour': '03-04',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 337.57,
#            'units': '€/Mwh'},
#  '04-05': {'date': '10-04-2022',
#            'hour': '04-05',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 329.76,
#            'units': '€/Mwh'},
#  '05-06': {'date': '10-04-2022',
#            'hour': '05-06',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 321.86,
#            'units': '€/Mwh'},
#  '06-07': {'date': '10-04-2022',
#            'hour': '06-07',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 328.15,
#            'units': '€/Mwh'},
#  '07-08': {'date': '10-04-2022',
#            'hour': '07-08',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 326.25,
#            'units': '€/Mwh'},
#  '08-09': {'date': '10-04-2022',
#            'hour': '08-09',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 324.72,
#            'units': '€/Mwh'},
#  '09-10': {'date': '10-04-2022',
#            'hour': '09-10',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 262.29,
#            'units': '€/Mwh'},
#  '10-11': {'date': '10-04-2022',
#            'hour': '10-11',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 197.53,
#            'units': '€/Mwh'},
#  '11-12': {'date': '10-04-2022',
#            'hour': '11-12',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 116.36,
#            'units': '€/Mwh'},
#  '12-13': {'date': '10-04-2022',
#            'hour': '12-13',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 28.21,
#            'units': '€/Mwh'},
#  '13-14': {'date': '10-04-2022',
#            'hour': '13-14',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 28.18,
#            'units': '€/Mwh'},
#  '14-15': {'date': '10-04-2022',
#            'hour': '14-15',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 28.2,
#            'units': '€/Mwh'},
#  '15-16': {'date': '10-04-2022',
#            'hour': '15-16',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 25.79,
#            'units': '€/Mwh'},
#  '16-17': {'date': '10-04-2022',
#            'hour': '16-17',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 26.42,
#            'units': '€/Mwh'},
#  '17-18': {'date': '10-04-2022',
#            'hour': '17-18',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 29.11,
#            'units': '€/Mwh'},
#  '18-19': {'date': '10-04-2022',
#            'hour': '18-19',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 45.03,
#            'units': '€/Mwh'},
#  '19-20': {'date': '10-04-2022',
#            'hour': '19-20',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 162.89,
#            'units': '€/Mwh'},
#  '20-21': {'date': '10-04-2022',
#            'hour': '20-21',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 286.65,
#            'units': '€/Mwh'},
#  '21-22': {'date': '10-04-2022',
#            'hour': '21-22',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 316.44,
#            'units': '€/Mwh'},
#  '22-23': {'date': '10-04-2022',
#            'hour': '22-23',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 303.35,
#            'units': '€/Mwh'},
#  '23-24': {'date': '10-04-2022',
#            'hour': '23-24',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 270.35,
#            'units': '€/Mwh'},
#  '_id': ObjectId('62532e39fdd924a15fe8653f')}
# {'00-01': {'date': '11-04-2022',
#            'hour': '00-01',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 203.38,
#            'units': '€/Mwh'},
#  '01-02': {'date': '11-04-2022',
#            'hour': '01-02',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 167.5,
#            'units': '€/Mwh'},
#  '02-03': {'date': '11-04-2022',
#            'hour': '02-03',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 149.34,
#            'units': '€/Mwh'},
#  '03-04': {'date': '11-04-2022',
#            'hour': '03-04',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 156.97,
#            'units': '€/Mwh'},
#  '04-05': {'date': '11-04-2022',
#            'hour': '04-05',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 176.15,
#            'units': '€/Mwh'},
#  '05-06': {'date': '11-04-2022',
#            'hour': '05-06',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 213.48,
#            'units': '€/Mwh'},
#  '06-07': {'date': '11-04-2022',
#            'hour': '06-07',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 219.8,
#            'units': '€/Mwh'},
#  '07-08': {'date': '11-04-2022',
#            'hour': '07-08',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 319.81,
#            'units': '€/Mwh'},
#  '08-09': {'date': '11-04-2022',
#            'hour': '08-09',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 361.44,
#            'units': '€/Mwh'},
#  '09-10': {'date': '11-04-2022',
#            'hour': '09-10',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 337.01,
#            'units': '€/Mwh'},
#  '10-11': {'date': '11-04-2022',
#            'hour': '10-11',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 339.75,
#            'units': '€/Mwh'},
#  '11-12': {'date': '11-04-2022',
#            'hour': '11-12',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 268.05,
#            'units': '€/Mwh'},
#  '12-13': {'date': '11-04-2022',
#            'hour': '12-13',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 233.59,
#            'units': '€/Mwh'},
#  '13-14': {'date': '11-04-2022',
#            'hour': '13-14',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 195.31,
#            'units': '€/Mwh'},
#  '14-15': {'date': '11-04-2022',
#            'hour': '14-15',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 118.35,
#            'units': '€/Mwh'},
#  '15-16': {'date': '11-04-2022',
#            'hour': '15-16',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 111.42,
#            'units': '€/Mwh'},
#  '16-17': {'date': '11-04-2022',
#            'hour': '16-17',
#            'is-cheap': True,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 120.62,
#            'units': '€/Mwh'},
#  '17-18': {'date': '11-04-2022',
#            'hour': '17-18',
#            'is-cheap': False,
#            'is-under-avg': True,
#            'market': 'PVPC',
#            'price': 179.98,
#            'units': '€/Mwh'},
#  '18-19': {'date': '11-04-2022',
#            'hour': '18-19',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 273.26,
#            'units': '€/Mwh'},
#  '19-20': {'date': '11-04-2022',
#            'hour': '19-20',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 373.24,
#            'units': '€/Mwh'},
#  '20-21': {'date': '11-04-2022',
#            'hour': '20-21',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 403.3,
#            'units': '€/Mwh'},
#  '21-22': {'date': '11-04-2022',
#            'hour': '21-22',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 404.51,
#            'units': '€/Mwh'},
#  '22-23': {'date': '11-04-2022',
#            'hour': '22-23',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 342.78,
#            'units': '€/Mwh'},
#  '23-24': {'date': '11-04-2022',
#            'hour': '23-24',
#            'is-cheap': False,
#            'is-under-avg': False,
#            'market': 'PVPC',
#            'price': 298.19,
#            'units': '€/Mwh'},
#  '_id': ObjectId('6253bcecfdd924a15fe86541')}

# %% [markdown]
# ## Nivell 2
# ### - Exercici 1
#
# Carega algunes consultes senzilles a un Pandas Dataframe.

# %%
col = db.test.find()

for item in col:
    print(item.keys())
    for rowns in item.keys():
        print(item[rowns])
# Out:
# dict_keys(['_id', '00-01', '01-02', '02-03', '03-04', '04-05', '05-06', '06-07', '07-08', '08-09', '09-10', '10-11', '11-12', '12-13', '13-14', '14-15', '15-16', '16-17', '17-18', '18-19', '19-20', '20-21', '21-22', '22-23', '23-24'])
# 62532e39fdd924a15fe8653f
# {'date': '10-04-2022', 'hour': '00-01', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 351.01, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '01-02', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 339.53, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '02-03', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 350.52, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '03-04', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 337.57, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '04-05', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 329.76, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '05-06', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 321.86, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '06-07', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 328.15, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '07-08', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 326.25, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '08-09', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 324.72, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '09-10', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 262.29, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '10-11', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 197.53, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '11-12', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 116.36, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '12-13', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 28.21, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '13-14', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 28.18, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '14-15', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 28.2, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '15-16', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 25.79, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '16-17', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 26.42, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '17-18', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 29.11, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '18-19', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 45.03, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '19-20', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 162.89, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '20-21', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 286.65, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '21-22', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 316.44, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '22-23', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 303.35, 'units': '€/Mwh'}
# {'date': '10-04-2022', 'hour': '23-24', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 270.35, 'units': '€/Mwh'}
# dict_keys(['_id', '00-01', '01-02', '02-03', '03-04', '04-05', '05-06', '06-07', '07-08', '08-09', '09-10', '10-11', '11-12', '12-13', '13-14', '14-15', '15-16', '16-17', '17-18', '18-19', '19-20', '20-21', '21-22', '22-23', '23-24'])
# 6253bcecfdd924a15fe86541
# {'date': '11-04-2022', 'hour': '00-01', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 203.38, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '01-02', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 167.5, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '02-03', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 149.34, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '03-04', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 156.97, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '04-05', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 176.15, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '05-06', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 213.48, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '06-07', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 219.8, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '07-08', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 319.81, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '08-09', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 361.44, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '09-10', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 337.01, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '10-11', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 339.75, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '11-12', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 268.05, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '12-13', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 233.59, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '13-14', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 195.31, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '14-15', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 118.35, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '15-16', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 111.42, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '16-17', 'is-cheap': True, 'is-under-avg': True, 'market': 'PVPC', 'price': 120.62, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '17-18', 'is-cheap': False, 'is-under-avg': True, 'market': 'PVPC', 'price': 179.98, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '18-19', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 273.26, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '19-20', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 373.24, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '20-21', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 403.3, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '21-22', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 404.51, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '22-23', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 342.78, 'units': '€/Mwh'}
# {'date': '11-04-2022', 'hour': '23-24', 'is-cheap': False, 'is-under-avg': False, 'market': 'PVPC', 'price': 298.19, 'units': '€/Mwh'}

# %%
cols = db.test.find()

doc=cols[1]
type(cols)
# Out:
# pymongo.cursor.Cursor

# %% [markdown]
# ## Nivell 3
# ### - Exercici 1
#
# Genera un resum estadístic de la informació que conté la base de dades.
